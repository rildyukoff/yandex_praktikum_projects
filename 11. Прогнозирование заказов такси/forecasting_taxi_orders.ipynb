# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Нужно построить модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Цели:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.

# %% [markdown]
# ## Подготовка

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt 
import seaborn as sns

from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.linear_model import LinearRegression 
from sklearn.ensemble import RandomForestRegressor 
from catboost import CatBoostRegressor

from sklearn.model_selection import cross_val_score, GridSearchCV , train_test_split, TimeSeriesSplit 

from sklearn.metrics import make_scorer, mean_squared_error

# %%
data = pd.read_csv('taxi.csv', index_col=[0], parse_dates=[0])

# %%
#Проверка хронологии расположения дат
display(data.index.is_monotonic)
data.sort_index(inplace=True)
display(data.head())
data.info()
# Out:
# True
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %%
#Ресемплирование по сумме заказа за каждый час
data = data.resample('1H').sum() 
data.plot()
plt.title('Сумма заказов за каждый час')
plt.xlabel('Дата')
plt.ylabel('Сумма')
plt.show()

# %% [markdown]
# <b>Вывод</b>
# Были рассмотрены и проверены на хронологический порадок данные

# %% [markdown]
# ## Анализ

# %%
#Начальная дата, конечная дата и за какой промежуток времени представлены данные
print('Начальная дата датасета:',data.index.min())
print('Конечная дата датасета:',data.index.max())
print('Количество дней в датасете:',data.index.max() - data.index.min())
print()
# Out:
# Начальная дата датасета: 2018-03-01 00:00:00
# Конечная дата датасета: 2018-08-31 23:00:00
# Количество дней в датасете: 183 days 23:00:00

# %%
data.describe()
# Out:
#         num_orders
# count  4416.000000
# mean     84.422781
# std      45.023853
# min       0.000000
# 25%      54.000000
# 50%      78.000000
# 75%     107.000000
# max     462.000000

# %%
#Ресемплирование по сумме заказов за каждый день
data.resample('1D').sum().plot()
plt.title('Сумма заказов за каждый день')
plt.xlabel('Дата')
plt.ylabel('Сумма')
plt.show()

# %%
#Скользящее среднее
data.rolling(10).mean().plot()
plt.title('Скользящее среднее')
plt.xlabel('Дата')
plt.ylabel('Среднее')
plt.show()

# %%
#Разбивка данных на тренд, сезонность и остаток
decomposed = seasonal_decompose(data)

plt.figure(figsize=(12, 20))

plt.subplot(311)
decomposed.trend.plot(ax=plt.gca())
plt.title('Тренд')
plt.xlabel('Дата')

plt.subplot(312)
decomposed.seasonal.plot(ax=plt.gca())
plt.title('Сезонность')
plt.xlabel('Дата')

plt.subplot(313)
decomposed.resid.plot(ax=plt.gca())
plt.title('Остаток')
plt.xlabel('Дата')
plt.tight_layout()

# %%
#Разбивка данных на тренд, сезонность и остаток за определенный период
decomposed = seasonal_decompose(data['2018-06-01':'2018-06-07'])

plt.figure(figsize=(12, 20))

plt.subplot(311)
decomposed.trend.plot(ax=plt.gca())
plt.title('Тренд')
plt.xlabel('Дата')

plt.subplot(312)
decomposed.seasonal.plot(ax=plt.gca())
plt.title('Сезонность')
plt.xlabel('Дата')

plt.subplot(313)
decomposed.resid.plot(ax=plt.gca())
plt.title('Остаток')
plt.xlabel('Дата')
plt.tight_layout()

# %%
#Стационарые ряды
data_plot = data.copy()
data_plot['rolling_mean'] = data_plot.rolling(30).mean()
data_plot['std'] = data_plot['num_orders'].rolling(30).std()
data_plot.plot(figsize=(18, 6))
plt.title('Стационарные ряды')
plt.xlabel('Дата')
plt.show()

# %%
data_shift = data - data.shift()
data_shift['mean'] = data_shift['num_orders'].rolling(30).mean()
data_shift['std'] = data_shift['num_orders'].rolling(30).std()
data_shift.plot(figsize=(18, 6))
plt.title('Стационарные ряды')
plt.xlabel('Дата')
plt.show()

# %% [markdown]
# <b>Вывод</b>
# Были построены графики:
# - ресемплирования сумм заказов за каждый день
# - скользящего среднего
# - тренда, сезонности и остатка
# - стационарные ряды

# %% [markdown]
# ## Обучение

# %%
#Функция для создания признаков
def make_features(data, max_lag, rolling_sum_size):
    data['month'] = data.index.month
    data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    data['hour'] = data.index.hour
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)
    data['rolling_sum'] = data['num_orders'].shift().rolling(rolling_sum_size).mean()

# %%
make_features(data, 24, 100)

# %%
data = data.dropna()

# %%
#Разбивка данных на фичи и таргеты
train, test = train_test_split(data, shuffle=False, test_size=0.1)

features_train = train.drop(['num_orders'], axis=1)
target_train = train['num_orders']
features_test = test.drop(['num_orders'], axis=1)
target_test = test['num_orders']

# %%
print(features_train.shape)
print(features_test.shape)
print(target_train.shape)
print(target_test.shape)
# Out:
# (3884, 29)
# (432, 29)
# (3884,)
# (432,)

# %%
#Функция для вычисления RMSE
def RMSE(target, predict):
    return (mean_squared_error(target, predict))**0.5
   
#С помощию функции make_scorer создаю метрику RMSE
RMSE_score = make_scorer(RMSE, greater_is_better=False)

# %%
# %%time
#Линейная регресиия
my_cv = TimeSeriesSplit(n_splits=3).split(features_train)

regression = LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

regression.fit(features_train, target_train)

regression_cv_score = pd.Series(cross_val_score(regression,features_train,target_train,scoring=RMSE_score,cv=my_cv)).mean()*(-1)
print('Среднее качество модели линейной регрессии на кросс-валидации:', regression_cv_score)
# Out:
# Среднее качество модели линейной регрессии на кросс-валидации: 28.200642009769023
# Wall time: 37.1 ms
# C:\Users\MSI\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# C:\Users\MSI\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# C:\Users\MSI\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# C:\Users\MSI\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
# %%time
#Случайны лес
my_cv = TimeSeriesSplit(n_splits=3).split(features_train)

forest = RandomForestRegressor()

forest_parametrs = { 'n_estimators': range(5, 30, 5),
                     'max_depth': range(1, 15, 2),
                     'min_samples_leaf': range(1,5),
                     'min_samples_split': range(2,8,2) }


forest_grid = GridSearchCV(forest, forest_parametrs, scoring=RMSE_score, cv=my_cv)
forest_grid.fit(features_train, target_train)
# Out:
# Wall time: 3min 15s
# GridSearchCV(cv=<generator object TimeSeriesSplit.split at 0x000002382701EDD0>,
#              estimator=RandomForestRegressor(),
#              param_grid={'max_depth': range(1, 15, 2),
#                          'min_samples_leaf': range(1, 5),
#                          'min_samples_split': range(2, 8, 2),
#                          'n_estimators': range(5, 30, 5)},
#              scoring=make_scorer(RMSE, greater_is_better=False))

# %%
# %%time

forest_params = forest_grid.best_params_
forest_score = forest_grid.score(features_train, target_train) * (-1)
print(forest_params)
print(forest_score)
print()
# Out:
# {'max_depth': 11, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 25}
# 14.220102792799127
#
# Wall time: 19.7 ms

# %%
# %%time
#CatBoostRegressor
my_cv = TimeSeriesSplit(n_splits=3).split(features_train)

model_cbr = CatBoostRegressor()

cbr_parametrs = {'learning_rate': [0.03, 0.1],
                'depth': [4, 6, 10]
               }


cbr_grid = GridSearchCV(model_cbr, cbr_parametrs, scoring=RMSE_score, cv=my_cv)
cbr_grid.fit(features_train, target_train, verbose=100)
# Out:
# 0:	learn: 28.8252514	total: 136ms	remaining: 2m 16s
# 100:	learn: 17.9542208	total: 285ms	remaining: 2.54s
# 200:	learn: 16.1781719	total: 382ms	remaining: 1.52s
# 300:	learn: 14.9320599	total: 473ms	remaining: 1.1s
# 400:	learn: 13.6396139	total: 564ms	remaining: 842ms
# 500:	learn: 12.5540594	total: 658ms	remaining: 656ms
# 600:	learn: 11.7318042	total: 750ms	remaining: 498ms
# 700:	learn: 11.0009932	total: 838ms	remaining: 357ms
# 800:	learn: 10.2931792	total: 938ms	remaining: 233ms
# 900:	learn: 9.6451514	total: 1.03s	remaining: 113ms
# 999:	learn: 9.0708048	total: 1.12s	remaining: 0us
# 0:	learn: 31.9422362	total: 3.11ms	remaining: 3.11s
# 100:	learn: 20.1802286	total: 191ms	remaining: 1.7s
# 200:	learn: 18.3938269	total: 311ms	remaining: 1.24s
# 300:	learn: 17.3748681	total: 426ms	remaining: 990ms
# 400:	learn: 16.4907964	total: 546ms	remaining: 816ms
# 500:	learn: 15.7141243	total: 665ms	remaining: 663ms
# 600:	learn: 15.0811883	total: 784ms	remaining: 521ms
# 700:	learn: 14.5079295	total: 897ms	remaining: 383ms
# 800:	learn: 14.0007928	total: 1.01s	remaining: 252ms
# 900:	learn: 13.4806931	total: 1.14s	remaining: 125ms
# 999:	learn: 12.9902288	total: 1.26s	remaining: 0us
# 0:	learn: 33.4768232	total: 6.1ms	remaining: 6.1s
# 100:	learn: 21.6331926	total: 210ms	remaining: 1.87s
# 200:	learn: 20.0182015	total: 343ms	remaining: 1.36s
# 300:	learn: 19.0686081	total: 477ms	remaining: 1.11s
# 400:	learn: 18.3097531	total: 608ms	remaining: 908ms
# 500:	learn: 17.5858680	total: 741ms	remaining: 738ms
# 600:	learn: 16.9672554	total: 871ms	remaining: 579ms
# 700:	learn: 16.4167170	total: 1s	remaining: 429ms
# 800:	learn: 15.9002380	total: 1.14s	remaining: 282ms
# 900:	learn: 15.4629666	total: 1.27s	remaining: 139ms
# 999:	learn: 15.0758511	total: 1.46s	remaining: 0us
# 0:	learn: 27.9462299	total: 1.48ms	remaining: 1.48s
# 100:	learn: 14.3117373	total: 104ms	remaining: 922ms
# 200:	learn: 11.0518490	total: 202ms	remaining: 801ms
# 300:	learn: 8.9367323	total: 291ms	remaining: 676ms
# 400:	learn: 7.4397421	total: 377ms	remaining: 564ms
# 500:	learn: 6.1770255	total: 469ms	remaining: 467ms
# 600:	learn: 5.2053725	total: 555ms	remaining: 369ms
# 700:	learn: 4.3952602	total: 641ms	remaining: 274ms
# 800:	learn: 3.7351803	total: 732ms	remaining: 182ms
# 900:	learn: 3.1736670	total: 822ms	remaining: 90.4ms
# 999:	learn: 2.6963095	total: 916ms	remaining: 0us
# 0:	learn: 31.1124779	total: 2.65ms	remaining: 2.65s
# 100:	learn: 17.2405760	total: 135ms	remaining: 1.2s
# 200:	learn: 14.8352404	total: 251ms	remaining: 997ms
# 300:	learn: 13.1367244	total: 363ms	remaining: 843ms
# 400:	learn: 11.7914526	total: 478ms	remaining: 715ms
# 500:	learn: 10.7113467	total: 591ms	remaining: 589ms
# 600:	learn: 9.7064226	total: 706ms	remaining: 469ms
# 700:	learn: 8.8359406	total: 824ms	remaining: 351ms
# 800:	learn: 8.0296326	total: 941ms	remaining: 234ms
# 900:	learn: 7.3039373	total: 1.05s	remaining: 116ms
# 999:	learn: 6.7198623	total: 1.17s	remaining: 0us
# 0:	learn: 32.5261821	total: 4.29ms	remaining: 4.28s
# 100:	learn: 18.9383815	total: 191ms	remaining: 1.7s
# 200:	learn: 16.7339357	total: 324ms	remaining: 1.29s
# 300:	learn: 15.2365036	total: 458ms	remaining: 1.06s
# 400:	learn: 14.0638064	total: 591ms	remaining: 882ms
# 500:	learn: 13.0046494	total: 722ms	remaining: 719ms
# 600:	learn: 12.1438884	total: 851ms	remaining: 565ms
# 700:	learn: 11.3966278	total: 982ms	remaining: 419ms
# 800:	learn: 10.6722826	total: 1.11s	remaining: 276ms
# 900:	learn: 9.9774097	total: 1.24s	remaining: 137ms
# 999:	learn: 9.3127809	total: 1.37s	remaining: 0us
# 0:	learn: 28.7951350	total: 9.04ms	remaining: 9.03s
# 100:	learn: 16.5138355	total: 274ms	remaining: 2.44s
# 200:	learn: 14.0397501	total: 453ms	remaining: 1.8s
# 300:	learn: 12.3997901	total: 642ms	remaining: 1.49s
# 400:	learn: 10.8432162	total: 827ms	remaining: 1.24s
# 500:	learn: 9.3525190	total: 1.01s	remaining: 1.01s
# 600:	learn: 8.2371094	total: 1.19s	remaining: 791ms
# 700:	learn: 7.2855523	total: 1.37s	remaining: 585ms
# 800:	learn: 6.5823481	total: 1.55s	remaining: 385ms
# 900:	learn: 5.8822528	total: 1.74s	remaining: 191ms
# 999:	learn: 5.2879029	total: 1.92s	remaining: 0us
# 0:	learn: 31.9000836	total: 6.14ms	remaining: 6.13s
# 100:	learn: 18.8507966	total: 276ms	remaining: 2.46s
# 200:	learn: 16.6949760	total: 507ms	remaining: 2.01s
# 300:	learn: 15.2639016	total: 738ms	remaining: 1.71s
# 400:	learn: 14.1676089	total: 975ms	remaining: 1.46s
# 500:	learn: 13.2862370	total: 1.2s	remaining: 1.2s
# 600:	learn: 12.3113527	total: 1.43s	remaining: 949ms
# 700:	learn: 11.5172488	total: 1.66s	remaining: 708ms
# 800:	learn: 10.8904185	total: 1.89s	remaining: 469ms
# 900:	learn: 10.2253573	total: 2.12s	remaining: 233ms
# 999:	learn: 9.6194290	total: 2.34s	remaining: 0us
# 0:	learn: 33.4256982	total: 5.79ms	remaining: 5.79s
# 100:	learn: 20.4224849	total: 308ms	remaining: 2.74s
# 200:	learn: 18.4247257	total: 571ms	remaining: 2.27s
# 300:	learn: 17.2559559	total: 848ms	remaining: 1.97s
# 400:	learn: 16.2578459	total: 1.11s	remaining: 1.67s
# 500:	learn: 15.1487654	total: 1.38s	remaining: 1.37s
# 600:	learn: 14.2190123	total: 1.65s	remaining: 1.09s
# 700:	learn: 13.4705098	total: 1.9s	remaining: 812ms
# 800:	learn: 12.7273638	total: 2.16s	remaining: 537ms
# 900:	learn: 12.0581479	total: 2.42s	remaining: 266ms
# 999:	learn: 11.4719644	total: 2.68s	remaining: 0us
# 0:	learn: 27.8443762	total: 4.92ms	remaining: 4.92s
# 100:	learn: 11.6503647	total: 253ms	remaining: 2.25s
# 200:	learn: 7.6641184	total: 433ms	remaining: 1.72s
# 300:	learn: 5.3648558	total: 618ms	remaining: 1.44s
# 400:	learn: 3.7992485	total: 800ms	remaining: 1.2s
# 500:	learn: 2.6655243	total: 986ms	remaining: 982ms
# 600:	learn: 1.8382440	total: 1.17s	remaining: 775ms
# 700:	learn: 1.3184574	total: 1.35s	remaining: 577ms
# 800:	learn: 0.9618499	total: 1.53s	remaining: 381ms
# 900:	learn: 0.7086050	total: 1.72s	remaining: 189ms
# 999:	learn: 0.5213553	total: 1.9s	remaining: 0us
# 0:	learn: 30.9714898	total: 4.29ms	remaining: 4.29s
# 100:	learn: 15.0151105	total: 274ms	remaining: 2.43s
# 200:	learn: 11.9206713	total: 500ms	remaining: 1.99s
# 300:	learn: 9.9392916	total: 729ms	remaining: 1.69s
# 400:	learn: 7.9928181	total: 958ms	remaining: 1.43s
# 500:	learn: 6.4001735	total: 1.27s	remaining: 1.27s
# 600:	learn: 5.1995138	total: 1.5s	remaining: 998ms
# 700:	learn: 4.2813852	total: 1.73s	remaining: 740ms
# 800:	learn: 3.5368803	total: 1.96s	remaining: 487ms
# 900:	learn: 2.9613723	total: 2.19s	remaining: 240ms
# 999:	learn: 2.4576827	total: 2.49s	remaining: 0us
# 0:	learn: 32.3548527	total: 6.08ms	remaining: 6.07s
# 100:	learn: 17.0162804	total: 294ms	remaining: 2.62s
# 200:	learn: 13.7642100	total: 553ms	remaining: 2.2s
# 300:	learn: 11.6792645	total: 810ms	remaining: 1.88s
# 400:	learn: 10.0800050	total: 1.12s	remaining: 1.67s
# 500:	learn: 8.7028135	total: 1.38s	remaining: 1.37s
# 600:	learn: 7.5419818	total: 1.63s	remaining: 1.08s
# 700:	learn: 6.5508341	total: 1.89s	remaining: 806ms
# 800:	learn: 5.6864000	total: 2.15s	remaining: 533ms
# 900:	learn: 4.9432560	total: 2.48s	remaining: 272ms
# 999:	learn: 4.3384910	total: 2.73s	remaining: 0us
# 0:	learn: 28.8302062	total: 45.8ms	remaining: 45.7s
# 100:	learn: 13.4516970	total: 3.56s	remaining: 31.7s
# 200:	learn: 8.9216863	total: 7.03s	remaining: 27.9s
# 300:	learn: 6.2247328	total: 10.5s	remaining: 24.5s
# 400:	learn: 4.5121722	total: 14s	remaining: 20.9s
# 500:	learn: 3.3386606	total: 17.5s	remaining: 17.4s
# 600:	learn: 2.5703638	total: 20.8s	remaining: 13.8s
# 700:	learn: 1.9197218	total: 24.1s	remaining: 10.3s
# 800:	learn: 1.4460669	total: 27.6s	remaining: 6.85s
# 900:	learn: 1.1113881	total: 31s	remaining: 3.41s
# 999:	learn: 0.8498381	total: 34.5s	remaining: 0us
# 0:	learn: 31.9069844	total: 57.9ms	remaining: 57.8s
# 100:	learn: 15.6578283	total: 4.34s	remaining: 38.6s
# 200:	learn: 11.7121197	total: 8.59s	remaining: 34.1s
# 300:	learn: 9.6108636	total: 12.9s	remaining: 29.9s
# 400:	learn: 7.9051025	total: 17.1s	remaining: 25.5s
# 500:	learn: 6.5194195	total: 21.3s	remaining: 21.2s
# 600:	learn: 5.4061328	total: 25.6s	remaining: 17s
# 700:	learn: 4.5071168	total: 29.8s	remaining: 12.7s
# 800:	learn: 3.7384930	total: 34.1s	remaining: 8.47s
# 900:	learn: 3.1022950	total: 38.4s	remaining: 4.21s
# 999:	learn: 2.6054996	total: 42.6s	remaining: 0us
# 0:	learn: 33.4164877	total: 45.9ms	remaining: 45.9s
# 100:	learn: 17.5904230	total: 4.76s	remaining: 42.4s
# 200:	learn: 14.0552341	total: 9.37s	remaining: 37.3s
# 300:	learn: 11.8750861	total: 14.1s	remaining: 32.8s
# 400:	learn: 10.2040848	total: 18.7s	remaining: 28s
# 500:	learn: 8.7603043	total: 23.3s	remaining: 23.2s
# 600:	learn: 7.5392818	total: 27.9s	remaining: 18.5s
# 700:	learn: 6.5940609	total: 32.5s	remaining: 13.9s
# 800:	learn: 5.6901193	total: 37s	remaining: 9.2s
# 900:	learn: 4.8986646	total: 41.6s	remaining: 4.58s
# 999:	learn: 4.2840366	total: 46.2s	remaining: 0us
# 0:	learn: 27.9545113	total: 45.8ms	remaining: 45.8s
# 100:	learn: 6.1318829	total: 3.52s	remaining: 31.3s
# 200:	learn: 2.3985189	total: 7.05s	remaining: 28s
# 300:	learn: 0.8422297	total: 10.6s	remaining: 24.5s
# 400:	learn: 0.3509288	total: 14s	remaining: 20.9s
# 500:	learn: 0.1437123	total: 17.4s	remaining: 17.3s
# 600:	learn: 0.0568038	total: 20.9s	remaining: 13.9s
# 700:	learn: 0.0248833	total: 24.3s	remaining: 10.4s
# 800:	learn: 0.0118659	total: 27.8s	remaining: 6.91s
# 900:	learn: 0.0047182	total: 31.2s	remaining: 3.43s
# 999:	learn: 0.0020434	total: 34.6s	remaining: 0us
# 0:	learn: 30.9866482	total: 63.1ms	remaining: 1m 3s
# 100:	learn: 9.2504096	total: 4.38s	remaining: 39s
# 200:	learn: 5.0546548	total: 8.68s	remaining: 34.5s
# 300:	learn: 2.7380979	total: 13s	remaining: 30.2s
# 400:	learn: 1.4500895	total: 17.3s	remaining: 25.8s
# 500:	learn: 0.7721792	total: 21.6s	remaining: 21.5s
# 600:	learn: 0.4387555	total: 25.9s	remaining: 17.2s
# 700:	learn: 0.2464812	total: 30.1s	remaining: 12.9s
# 800:	learn: 0.1435963	total: 34.4s	remaining: 8.55s
# 900:	learn: 0.0793410	total: 38.7s	remaining: 4.25s
# 999:	learn: 0.0456422	total: 42.9s	remaining: 0us
# 0:	learn: 32.3181643	total: 62ms	remaining: 1m 1s
# 100:	learn: 10.8619336	total: 4.77s	remaining: 42.5s
# 200:	learn: 6.3189160	total: 9.48s	remaining: 37.7s
# 300:	learn: 3.8159521	total: 14.2s	remaining: 33.1s
# 400:	learn: 2.3370567	total: 18.9s	remaining: 28.3s
# 500:	learn: 1.4744587	total: 23.7s	remaining: 23.6s
# 600:	learn: 0.8940866	total: 28.5s	remaining: 18.9s
# 700:	learn: 0.5527742	total: 33.3s	remaining: 14.2s
# 800:	learn: 0.3566795	total: 38s	remaining: 9.43s
# 900:	learn: 0.2314484	total: 42.6s	remaining: 4.68s
# 999:	learn: 0.1604780	total: 47.3s	remaining: 0us
# 0:	learn: 38.1982933	total: 5.56ms	remaining: 5.56s
# 100:	learn: 24.2910629	total: 219ms	remaining: 1.95s
# 200:	learn: 22.7529456	total: 380ms	remaining: 1.51s
# 300:	learn: 21.7867358	total: 537ms	remaining: 1.25s
# 400:	learn: 20.8238648	total: 701ms	remaining: 1.05s
# 500:	learn: 20.0105500	total: 860ms	remaining: 857ms
# 600:	learn: 19.3253240	total: 1.02s	remaining: 678ms
# 700:	learn: 18.7516431	total: 1.18s	remaining: 504ms
# 800:	learn: 18.2306287	total: 1.4s	remaining: 348ms
# 900:	learn: 17.7735142	total: 1.56s	remaining: 171ms
# 999:	learn: 17.3451322	total: 1.71s	remaining: 0us
# Wall time: 4min 38s
# GridSearchCV(cv=<generator object TimeSeriesSplit.split at 0x0000023826FEF430>,
#              estimator=<catboost.core.CatBoostRegressor object at 0x000002382911D370>,
#              param_grid={'depth': [4, 6, 10], 'learning_rate': [0.03, 0.1]},
#              scoring=make_scorer(RMSE, greater_is_better=False))

# %%
# %%time

cbr_params = cbr_grid.best_params_
cbr_score = cbr_grid.score(features_train, target_train) * (-1)
print(cbr_params)
print(cbr_score)
print()
# Out:
# {'depth': 4, 'learning_rate': 0.03}
# 17.345132244233966
#
# Wall time: 16 ms

# %% [markdown]
# <b>Вывод</b>
# Обучены три модели: линейная регрессия, случайный лес, CatBoostRegressor, на тренировочных выборках, и подобраны параметры с помощью кросс-валидации. Получены RMSE моделей.

# %% [markdown]
# ## Тестирование

# %%
# %%time
#Обучаю модель
regression_model = LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regression_model.fit(features_train, target_train)
regression_model_predictions = regression_model.predict(features_test)

#Определяю метрику RMSE
regression_RMSE = round(RMSE(target_test, regression_model_predictions), 3)
print('RMSE модели Линейной регрессии:', regression_RMSE)
# Out:
# RMSE модели Линейной регрессии: 47.083
# Wall time: 20.2 ms
# C:\Users\MSI\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
# %%time
#Обучаю модель на оптимальных гиперпараметрах
forest_model = RandomForestRegressor(random_state=42,
                                     max_depth=forest_params['max_depth'],
                                     min_samples_leaf = forest_params['min_samples_leaf'],
                                     min_samples_split = forest_params['min_samples_split'],
                                     n_estimators = forest_params['n_estimators'])

forest_model.fit(features_train, target_train)
forest_model_predictions = forest_model.predict(features_test)

#Определяю метрику RMSE
forest_RMSE = round(RMSE(target_test, forest_model_predictions), 3)
print('RMSE модели Случайного леса:', forest_RMSE)
# Out:
# RMSE модели Случайного леса: 45.163
# Wall time: 902 ms

# %%
# %%time
model_cbr_test = CatBoostRegressor(learning_rate=cbr_params['learning_rate'], depth=cbr_params['depth'])

model_cbr_test.fit(features_train, target_train, verbose=100)
cbr_test_predictions = model_cbr_test.predict(features_test)

#Определяю метрику RMSE
cbr_RMSE = round(RMSE(target_test, cbr_test_predictions), 3)
print('RMSE модели CatBoostRegressor:', cbr_RMSE)
# Out:
# 0:	learn: 38.1982933	total: 6.14ms	remaining: 6.14s
# 100:	learn: 24.2910629	total: 204ms	remaining: 1.82s
# 200:	learn: 22.7529456	total: 360ms	remaining: 1.43s
# 300:	learn: 21.7867358	total: 516ms	remaining: 1.2s
# 400:	learn: 20.8238648	total: 673ms	remaining: 1s
# 500:	learn: 20.0105500	total: 829ms	remaining: 826ms
# 600:	learn: 19.3253240	total: 991ms	remaining: 658ms
# 700:	learn: 18.7516431	total: 1.15s	remaining: 490ms
# 800:	learn: 18.2306287	total: 1.31s	remaining: 325ms
# 900:	learn: 17.7735142	total: 1.46s	remaining: 161ms
# 999:	learn: 17.3451322	total: 1.61s	remaining: 0us
# RMSE модели CatBoostRegressor: 40.933
# Wall time: 1.81 s

# %% [markdown]
# <b>Вывод</b>
# Модели проверены на тестовых выборках. Лучше всех показала себя модель CatBoostRegressor с RMSE - 40.933, что соответсвует условиям задачи
